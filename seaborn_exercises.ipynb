# %% [markdown]
# Use seaborn's load_dataset function to load the iris database to answer the following questions:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import env

# %%
iris = sns.load_dataset('iris')

iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 1. What does the distribution of petal lengths look like?

# %%
sns.displot(iris["petal_length"])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
iris.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 2. Is there a relationship between petal length and petal width?

# %%
sns.relplot(data=iris, x='petal_length', y='petal_width', hue= 'species')
plt.show()
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 3. Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
sns.relplot(x='sepal_length', y='sepal_width',hue= 'species', data=iris)
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 4. Which features would be best used to predict species?

# %%
sns.pairplot(iris,hue="species", corner = True)
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='petal_width', y='petal_length',hue='species', data=iris)
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 1. Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice? Datasets are all very similar.

# %%
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.groupby(['dataset']).describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %% [markdown]
# Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
sns.relplot(data=anscombe,x="x",y="y",col="dataset")
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 2. Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
from pydataset import data

# %%
#data('InsectSprays', show_doc=True)

# %%
insect_sprays = data('InsectSprays')
insect_sprays.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
sns.boxplot(data=insect_sprays, x='spray', y='count')
# Out:
# <Axes: xlabel='spray', ylabel='count'>

# %% [markdown]
# 3. Load the swiss dataset from pydataset and read it's documentation. Create visualizations to answer the following questions:

# %%
swiss = data('swiss')
swiss.head()
#data('swiss', show_doc=True)
swiss.describe()
# Out:
#        Fertility  Agriculture  Examination  Education   Catholic  \
# count  47.000000    47.000000    47.000000  47.000000   47.00000
# mean   70.142553    50.659574    16.489362  10.978723   41.14383
# std    12.491697    22.711218     7.977883   9.615407   41.70485
# min    35.000000     1.200000     3.000000   1.000000    2.15000
# 25%    64.700000    35.900000    12.000000   6.000000    5.19500
# 50%    70.400000    54.100000    16.000000   8.000000   15.14000
# 75%    78.450000    67.650000    22.000000  12.000000   93.12500
# max    92.500000    89.700000    37.000000  53.000000  100.00000
#
#        Infant.Mortality
# count         47.000000
# mean          19.942553
# std            2.912697
# min           10.800000
# 25%           18.150000
# 50%           20.000000
# 75%           21.700000
# max           26.600000

# %% [markdown]
# Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
swiss.T
# Out:
#                   Courtelary  Delemont  Franches-Mnt  Moutier  Neuveville  \
# Fertility              80.20     83.10          92.5    85.80       76.90
# Agriculture            17.00     45.10          39.7    36.50       43.50
# Examination            15.00      6.00           5.0    12.00       17.00
# Education              12.00      9.00           5.0     7.00       15.00
# Catholic                9.96     84.84          93.4    33.77        5.16
# Infant.Mortality       22.20     22.20          20.2    20.30       20.60
#
#                   Porrentruy  Broye  Glane  Gruyere  Sarine  ...   Sion  \
# Fertility              76.10  83.80  92.40    82.40   82.90  ...  79.30
# Agriculture            35.30  70.20  67.80    53.30   45.20  ...  63.10
# Examination             9.00  16.00  14.00    12.00   16.00  ...  13.00
# Education               7.00   7.00   8.00     7.00   13.00  ...  13.00
# Catholic               90.57  92.85  97.16    97.67   91.38  ...  96.83
# Infant.Mortality       26.60  23.60  24.90    21.00   24.40  ...  18.10
#
#                   Boudry  La Chauxdfnd  Le Locle  Neuchatel  Val de Ruz  \
# Fertility          70.40         65.70     72.70      64.40       77.60
# Agriculture        38.40          7.70     16.70      17.60       37.60
# Examination        26.00         29.00     22.00      35.00       15.00
# Education          12.00         11.00     13.00      32.00        7.00
# Catholic            5.62         13.79     11.22      16.92        4.97
# Infant.Mortality   20.30         20.50     18.90      23.00       20.00
#
#                   ValdeTravers  V. De Geneve  Rive Droite  Rive Gauche
# Fertility                67.60         35.00        44.70        42.80
# Agriculture              18.70          1.20        46.60        27.70
# Examination              25.00         37.00        16.00        22.00
# Education                 7.00         53.00        29.00        29.00
# Catholic                  8.65         42.34        50.43        58.33
# Infant.Mortality         19.50         18.00        18.20        19.30
#
# [6 rows x 47 columns]

# %%
swiss['is_catholic'] = np.where(swiss.Catholic >= 50, 'YES', 'NO')

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality is_catholic
# Courtelary                22.2          NO
# Delemont                  22.2         YES
# Franches-Mnt              20.2         YES
# Moutier                   20.3          NO
# Neuveville                20.6          NO

# %%
sns.boxplot(data=swiss, )

# %%
sns.histplot(swiss.is_catholic)
plt.show()

# %% [markdown]
# Does whether or not a province is Catholic influence fertility?

# %%
sns.displot(data=swiss, x='Fertility', kde=True, hue= 'is_catholic', col='is_catholic')
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# What measure correlates most strongly with fertility?

# %%
sns.relplot(data=swiss, x='Infant.Mortality', y='Examination', hue='Fertility')#, col='size', hue='smoker')
plt.show()
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(swiss,hue="Fertility")
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 4. Load the chipotle dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
def get_db_url(user, password, host, database):
    return (f'mysql+pymysql://{user}:{password}@{host}/{db}')

# %%
chipotle = pd.read_sql('select * from orders', url)
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#      item_price
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
# ...         ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
#
# [4622 rows x 6 columns]

# %%
chipotle.item_price = chipotle.item_price.str.strip('$').astype(float)

# %%
items_chipotle = chipotle.groupby('item_name')[['quantity','item_price']].sum()
items_chipotle.head()
# Out:
#                        quantity  item_price
# item_name
# 6 Pack Soft Drink            55      356.95
# Barbacoa Bowl                66      672.36
# Barbacoa Burrito             91      894.75
# Barbacoa Crispy Tacos        12      120.21
# Barbacoa Salad Bowl          10      106.40

# %%
top_items = items_chipotle.sort_values('quantity', ascending=False).head(4)
top_items
# Out:
#                      quantity  item_price
# item_name
# Chicken Bowl              761     7342.73
# Chicken Burrito           591     5575.82
# Chips and Guacamole       506     2201.04
# Steak Burrito             386     3851.43

# %%
top_items.reset_index()
# Out:
#              item_name  quantity  item_price
# 0         Chicken Bowl       761     7342.73
# 1      Chicken Burrito       591     5575.82
# 2  Chips and Guacamole       506     2201.04
# 3        Steak Burrito       386     3851.43

# %%
sns.barplot(data=top_items, y=top_items.index, x='item_price');

# %% [markdown]
# 5. Load the sleepstudy dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleepstudy = data('sleepstudy')
sleepstudy.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
sleepstudy.dtypes
# Out:
# Reaction    float64
# Days          int64
# Subject       int64
# dtype: object

# %%
sleepstudy.Subject.nunique()
# Out:
# 18

# %%
sns.lineplot(data=sleepstudy, x='Days', y='Reaction', hue='Subject', alpha=0.4)
sns.lineplot(data=sleepstudy, x='Days', y='Reaction', c='black', linewidth=6)
plt.show()
